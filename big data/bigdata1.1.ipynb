# %% [markdown]
# ## Inventario instalaciones fotovoltaicas

# %% [markdown]
# ##### _Grupo Erasmus_

# %% [markdown]
# Importamos los datos descargados sobre el inventario de las instalaciones fotovoltaicas desde el año 2020 hasta 2024

# %%
import pandas as pd
# Activar el modo Copy-on-Write
pd.options.mode.copy_on_write = True

# Lista de archivos CSV
archivos = ['inventario_instalaciones_fotovoltaicas_2020.csv', 
            'inventario_instalaciones_fotovoltaicas_2021.csv', 
            'inventario_instalaciones_fotovoltaicas_2022.csv', 
            'inventario_instalaciones_fotovoltaicas_2023.csv', 
            'inventario_instalaciones_fotovoltaicas_2024.csv']

# Leer y combinar todos los archivos en un solo DataFrame, asegurando que es una copia independiente
dataframes = [pd.read_csv(archivo, encoding='ISO-8859-1', sep=';') for archivo in archivos]
inventario_completo = pd.concat(dataframes, ignore_index=True)

# Mostrar las primeras filas del DataFrame concatenado
inventario_completo
# Out:
#      Número  Código Ayto                                     Centro  \
# 0       1.0       2178.0                  BIBLIOTECA ÁNGEL GONZALEZ
# 1       2.0        782.0                  BIBLIOTECA IVÁN DE VARGAS
# 2       3.0       2096.0     BIBLIOTECA EUGENIO TRIAS (CASA FIERAS)
# 3       4.0       1046.0                                 PLANETARIO
# 4       5.0       2143.0                            MADRID EMPRENDE
# ..      ...          ...                                        ...
# 737   171.0          NaN  CENTRO MUNICIPAL DE RECOGIDAS TRECE ROSAS
# 738   172.0          NaN                             CDM EL QUIJOTE
# 739   173.0          NaN                               CDM MOSCARDO
# 740   174.0          NaN                CID VILLA DE VALLECAS / OAC
# 741   175.0          NaN         ALMACEN BOMBEROS VILLA DE VALLECAS
#
#                                        Dirección Coordenada-X Coordenada-Y  \
# 0                  C/ GRANJA DE TORREHERMOSA, 2        434954      4472113
# 1                         C/ DOCTOR LETAMENDI, 1       439775      4473962
# 2                 AV/ MENENDEZ PELAYO , 10-3 BJ        442345      4474221
# 3                              AV/ PLANETARIO 16       441830      4471375
# 4                                    C/CIDRO, 3        436689      4468938
# ..                                           ...          ...          ...
# 737  AVENIDA DE LAS TRECE ROSAS, 5, 28017 MADRID     445062.0    4475080.0
# 738                             CALLE NUMANCIA,2     439587.0    4478360.0
# 739                   CALLE PILAR DE ZARAGOZA 93     440125.0    4471120.0
# 740                     CALLE REAL DE ARGANDA 64     447858.0    4470029.0
# 741              CALLE EL REAL DE SAN VICENTE 61     446228.0    4468926.0
#
#        Latitud             Longitud Superficie (m2) Uso del edificio  ...  \
# 0    40.397075  -3.7664885474841500             NaN         cultural  ...
# 1    40.414103  -3.7098591212735800             NaN         cultural  ...
# 2    40.416609  -3.6795930368034800             NaN         cultural  ...
# 3    40.390944   -3.685391155439890           3.062         cultural  ...
# 4    40.368616    -3.74573026512817             NaN   administrativo  ...
# ..         ...                  ...             ...              ...  ...
# 737  40.424542            -3.647631             NaN   medioambiental  ...
# 738  40.453707            -3.712486             NaN        deportivo  ...
# 739  40.388522            -3.705459             NaN        deportivo  ...
# 740  40.379215            -3.614259             NaN        seguridad  ...
# 741  40.369172             -3.63337             NaN        seguridad  ...
#
#     Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 0           NaN         NaN         NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN         NaN         NaN          NaN
# 2           NaN         NaN         NaN         NaN         NaN          NaN
# 3           NaN         NaN         NaN         NaN         NaN          NaN
# 4           NaN         NaN         NaN         NaN         NaN          NaN
# ..          ...         ...         ...         ...         ...          ...
# 737         NaN         NaN         NaN         NaN         NaN          NaN
# 738         NaN         NaN         NaN         NaN         NaN          NaN
# 739         NaN         NaN         NaN         NaN         NaN          NaN
# 740         NaN         NaN         NaN         NaN         NaN          NaN
# 741         NaN         NaN         NaN         NaN         NaN          NaN
#
#      Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0            NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN
# ..           ...         ...         ...         ...
# 737          NaN         NaN         NaN         NaN
# 738          NaN         NaN         NaN         NaN
# 739          NaN         NaN         NaN         NaN
# 740          NaN         NaN         NaN         NaN
# 741          NaN         NaN         NaN         NaN
#
# [742 rows x 30 columns]

# %% [markdown]
# Comprobamos si hay nulos con la función *info()* en el fichero.

# %%
inventario_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número               364 non-null    float64
#  1   Código Ayto          324 non-null    float64
#  2   Centro               630 non-null    object
#  3   Dirección            364 non-null    object
#  4   Coordenada-X         629 non-null    object
#  5   Coordenada-Y         629 non-null    object
#  6   Latitud              630 non-null    float64
#  7   Longitud             630 non-null    object
#  8   Superficie (m2)      120 non-null    object
#  9   Uso del edificio     630 non-null    object
#  10  Adscripción          364 non-null    object
#  11  Distrito             630 non-null    object
#  12  Potencia KWp         515 non-null    object
#  13  Empresa instaladora  451 non-null    object
#  14  Puesta en servicio   584 non-null    object
#  15  ï»¿NÃºmero           266 non-null    float64
#  16  CÃ³digo Ayto         228 non-null    float64
#  17  DirecciÃ³n           266 non-null    object
#  18  AdscripciÃ³n         266 non-null    object
#  19  Potencia KW          115 non-null    object
#  20  Unnamed: 15          0 non-null      float64
#  21  Unnamed: 16          0 non-null      float64
#  22  Unnamed: 17          0 non-null      float64
#  23  Unnamed: 18          0 non-null      float64
#  24  Unnamed: 19          0 non-null      float64
#  25  Unnamed: 20          0 non-null      float64
#  26  Unnamed: 21          0 non-null      float64
#  27  Unnamed: 22          0 non-null      float64
#  28  Unnamed: 23          0 non-null      float64
#  29  Unnamed: 24          0 non-null      float64
# dtypes: float64(15), object(15)
# memory usage: 174.0+ KB

# %%
inventario_completo.columns
# Out:
# Index(['Número', 'Código Ayto', 'Centro', 'Dirección', 'Coordenada-X',
#        'Coordenada-Y', 'Latitud', 'Longitud', 'Superficie (m2)',
#        'Uso del edificio', 'Adscripción', 'Distrito', 'Potencia KWp',
#        'Empresa instaladora', 'Puesta en servicio', 'ï»¿NÃºmero',
#        'CÃ³digo Ayto', 'DirecciÃ³n', 'AdscripciÃ³n', 'Potencia KW',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
# Eliminar columnas que solo contienen valores NaN
inventario_completo = inventario_completo.dropna(axis=1, how='all')
inventario_completo.columns
# Out:
# Index(['Número', 'Código Ayto', 'Centro', 'Dirección', 'Coordenada-X',
#        'Coordenada-Y', 'Latitud', 'Longitud', 'Superficie (m2)',
#        'Uso del edificio', 'Adscripción', 'Distrito', 'Potencia KWp',
#        'Empresa instaladora', 'Puesta en servicio', 'ï»¿NÃºmero',
#        'CÃ³digo Ayto', 'DirecciÃ³n', 'AdscripciÃ³n', 'Potencia KW'],
#       dtype='object')

# %% [markdown]
# Borramos los posibles datos duplicados.

# %%
inventario_completo.drop_duplicates(inplace=True)

# %%
inventario_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 631 entries, 0 to 741
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número               364 non-null    float64
#  1   Código Ayto          324 non-null    float64
#  2   Centro               630 non-null    object
#  3   Dirección            364 non-null    object
#  4   Coordenada-X         629 non-null    object
#  5   Coordenada-Y         629 non-null    object
#  6   Latitud              630 non-null    float64
#  7   Longitud             630 non-null    object
#  8   Superficie (m2)      120 non-null    object
#  9   Uso del edificio     630 non-null    object
#  10  Adscripción          364 non-null    object
#  11  Distrito             630 non-null    object
#  12  Potencia KWp         515 non-null    object
#  13  Empresa instaladora  451 non-null    object
#  14  Puesta en servicio   584 non-null    object
#  15  ï»¿NÃºmero           266 non-null    float64
#  16  CÃ³digo Ayto         228 non-null    float64
#  17  DirecciÃ³n           266 non-null    object
#  18  AdscripciÃ³n         266 non-null    object
#  19  Potencia KW          115 non-null    object
# dtypes: float64(5), object(15)
# memory usage: 103.5+ KB

# %%
inventario_completo.head()
# Out:
#    Número  Código Ayto                                  Centro  \
# 0     1.0       2178.0               BIBLIOTECA ÁNGEL GONZALEZ
# 1     2.0        782.0               BIBLIOTECA IVÁN DE VARGAS
# 2     3.0       2096.0  BIBLIOTECA EUGENIO TRIAS (CASA FIERAS)
# 3     4.0       1046.0                              PLANETARIO
# 4     5.0       2143.0                         MADRID EMPRENDE
#
#                         Dirección Coordenada-X Coordenada-Y    Latitud  \
# 0   C/ GRANJA DE TORREHERMOSA, 2        434954      4472113  40.397075
# 1          C/ DOCTOR LETAMENDI, 1       439775      4473962  40.414103
# 2  AV/ MENENDEZ PELAYO , 10-3 BJ        442345      4474221  40.416609
# 3               AV/ PLANETARIO 16       441830      4471375  40.390944
# 4                     C/CIDRO, 3        436689      4468938  40.368616
#
#               Longitud Superficie (m2) Uso del edificio  \
# 0  -3.7664885474841500             NaN         cultural
# 1  -3.7098591212735800             NaN         cultural
# 2  -3.6795930368034800             NaN         cultural
# 3   -3.685391155439890           3.062         cultural
# 4    -3.74573026512817             NaN   administrativo
#
#                           Adscripción       Distrito Potencia KWp  \
# 0      AG Cultura Turismo y Deportes         Latina            20
# 1      AG Cultura Turismo y Deportes         Centro             3
# 2      AG Cultura Turismo y Deportes         Retiro           8,2
# 3      AG Cultura Turismo y Deportes     Arganzuela            25
# 4   AG Economía, Innovación y Empleo    Carabanchel            10
#
#   Empresa instaladora Puesta en servicio  ï»¿NÃºmero  CÃ³digo Ayto DirecciÃ³n  \
# 0               ORTIZ         31/07/2019         NaN           NaN        NaN
# 1               ORTIZ         24/07/2019         NaN           NaN        NaN
# 2               ORTIZ         24/07/2019         NaN           NaN        NaN
# 3              FULTON         13/09/2019         NaN           NaN        NaN
# 4                 NaN                NaN         NaN           NaN        NaN
#
#   AdscripciÃ³n Potencia KW
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN

# %%
# Eliminar las columnas con nombres con errores de codificación
columns_to_drop = ['ï»¿NÃºmero', 'CÃ³digo Ayto', 'DirecciÃ³n', 'AdscripciÃ³n', 'Potencia KW']

# Eliminar las columnas del DataFrame
inventario_completo.drop(columns=columns_to_drop, inplace=True)

# Verificar que las columnas han sido eliminadas
inventario_completo.columns
# Out:
# Index(['Número', 'Código Ayto', 'Centro', 'Dirección', 'Coordenada-X',
#        'Coordenada-Y', 'Latitud', 'Longitud', 'Superficie (m2)',
#        'Uso del edificio', 'Adscripción', 'Distrito', 'Potencia KWp',
#        'Empresa instaladora', 'Puesta en servicio'],
#       dtype='object')

# %%
inventario_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 631 entries, 0 to 741
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número               364 non-null    float64
#  1   Código Ayto          324 non-null    float64
#  2   Centro               630 non-null    object
#  3   Dirección            364 non-null    object
#  4   Coordenada-X         629 non-null    object
#  5   Coordenada-Y         629 non-null    object
#  6   Latitud              630 non-null    float64
#  7   Longitud             630 non-null    object
#  8   Superficie (m2)      120 non-null    object
#  9   Uso del edificio     630 non-null    object
#  10  Adscripción          364 non-null    object
#  11  Distrito             630 non-null    object
#  12  Potencia KWp         515 non-null    object
#  13  Empresa instaladora  451 non-null    object
#  14  Puesta en servicio   584 non-null    object
# dtypes: float64(3), object(12)
# memory usage: 78.9+ KB

# %%
# Ver los datos de cada columna
print("Columna: Número")
print(inventario_completo['Número'].head(), "\n")

print("Columna: Código Ayto")
print(inventario_completo['Código Ayto'].head(), "\n")

print("Columna: Centro")
print(inventario_completo['Centro'].head(), "\n")

print("Columna: Dirección")
print(inventario_completo['Dirección'].head(), "\n")

print("Columna: Coordenada-X")
print(inventario_completo['Coordenada-X'].head(), "\n")

print("Columna: Coordenada-Y")
print(inventario_completo['Coordenada-Y'].head(), "\n")

print("Columna: Latitud")
print(inventario_completo['Latitud'].head(), "\n")

print("Columna: Longitud")
print(inventario_completo['Longitud'].head(), "\n")

print("Columna: Superficie (m2)")
print(inventario_completo['Superficie (m2)'].head(), "\n")

print("Columna: Uso del edificio")
print(inventario_completo['Uso del edificio'].head(), "\n")

print("Columna: Adscripción")
print(inventario_completo['Adscripción'].head(), "\n")

print("Columna: Distrito")
print(inventario_completo['Distrito'].head(), "\n")

print("Columna: Potencia KWp")
print(inventario_completo['Potencia KWp'].head(), "\n")

print("Columna: Empresa instaladora")
print(inventario_completo['Empresa instaladora'].head(), "\n")

print("Columna: Puesta en servicio")
print(inventario_completo['Puesta en servicio'].head(), "\n")
# Out:
# Columna: Número
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: Número, dtype: float64
#
# Columna: Código Ayto
# 0    2178.0
# 1     782.0
# 2    2096.0
# 3    1046.0
# 4    2143.0
# Name: Código Ayto, dtype: float64
#
# Columna: Centro
# 0                 BIBLIOTECA ÁNGEL GONZALEZ
# 1                 BIBLIOTECA IVÁN DE VARGAS
# 2    BIBLIOTECA EUGENIO TRIAS (CASA FIERAS)
# 3                                PLANETARIO
# 4                           MADRID EMPRENDE
# Name: Centro, dtype: object
#
# Columna: Dirección
# 0     C/ GRANJA DE TORREHERMOSA, 2
# 1            C/ DOCTOR LETAMENDI, 1
# 2    AV/ MENENDEZ PELAYO , 10-3 BJ
# 3                 AV/ PLANETARIO 16
# 4                       C/CIDRO, 3
# Name: Dirección, dtype: object
#
# Columna: Coordenada-X
# 0    434954
# 1    439775
# 2    442345
# 3    441830
# 4    436689
# Name: Coordenada-X, dtype: object
#
# Columna: Coordenada-Y
# 0    4472113
# 1    4473962
# 2    4474221
# 3    4471375
# 4    4468938
# Name: Coordenada-Y, dtype: object
#
# Columna: Latitud
# 0    40.397075
# 1    40.414103
# 2    40.416609
# 3    40.390944
# 4    40.368616
# Name: Latitud, dtype: float64
#
# Columna: Longitud
# 0    -3.7664885474841500
# 1    -3.7098591212735800
# 2    -3.6795930368034800
# 3     -3.685391155439890
# 4      -3.74573026512817
# Name: Longitud, dtype: object
#
# Columna: Superficie (m2)
# 0      NaN
# 1      NaN
# 2      NaN
# 3    3.062
# 4      NaN
# Name: Superficie (m2), dtype: object
#
# Columna: Uso del edificio
# 0          cultural
# 1          cultural
# 2          cultural
# 3          cultural
# 4    administrativo
# Name: Uso del edificio, dtype: object
#
# Columna: Adscripción
# 0        AG Cultura Turismo y Deportes
# 1        AG Cultura Turismo y Deportes
# 2        AG Cultura Turismo y Deportes
# 3        AG Cultura Turismo y Deportes
# 4     AG Economía, Innovación y Empleo
# Name: Adscripción, dtype: object
#
# Columna: Distrito
# 0          Latina
# 1          Centro
# 2          Retiro
# 3      Arganzuela
# 4     Carabanchel
# Name: Distrito, dtype: object
#
# Columna: Potencia KWp
# 0     20
# 1      3
# 2    8,2
# 3     25
# 4     10
# Name: Potencia KWp, dtype: object
#
# Columna: Empresa instaladora
# 0     ORTIZ
# 1     ORTIZ
# 2     ORTIZ
# 3    FULTON
# 4       NaN
# Name: Empresa instaladora, dtype: object
#
# Columna: Puesta en servicio
# 0    31/07/2019
# 1    24/07/2019
# 2    24/07/2019
# 3    13/09/2019
# 4           NaN
# Name: Puesta en servicio, dtype: object

# %%
print("Columna: Puesta en servicio")
print(inventario_completo['Puesta en servicio'], "\n")
# Out:
# Columna: Puesta en servicio
# 0      31/07/2019
# 1      24/07/2019
# 2      24/07/2019
# 3      13/09/2019
# 4             NaN
#           ...
# 737    01/07/2024
# 738    12/09/2024
# 739    11/09/2024
# 740    11/09/2024
# 741    03/04/2024
# Name: Puesta en servicio, Length: 631, dtype: object

# %%
# Convertir 'Superficie (m2)' a numérico (si tiene valores no numéricos, los convertirá a NaN)
inventario_completo['Superficie (m2)'] = pd.to_numeric(inventario_completo['Superficie (m2)'], errors='coerce')

# Convertir 'Potencia KWp' a numérico (similar a la columna anterior)
inventario_completo['Potencia KWp'] = pd.to_numeric(inventario_completo['Potencia KWp'], errors='coerce')
# Convertir las columnas de coordenadas y otras columnas numéricas que están como 'object' a 'float'
inventario_completo['Coordenada-X'] = pd.to_numeric(inventario_completo['Coordenada-X'], errors='coerce')
inventario_completo['Coordenada-Y'] = pd.to_numeric(inventario_completo['Coordenada-Y'], errors='coerce')
inventario_completo['Latitud'] = pd.to_numeric(inventario_completo['Latitud'], errors='coerce')
inventario_completo['Longitud'] = pd.to_numeric(inventario_completo['Longitud'], errors='coerce')

# %%
# Convertir la columna 'Puesta en servicio' a formato de fecha especificando que el día va primero
inventario_completo['Puesta en servicio'] = pd.to_datetime(inventario_completo['Puesta en servicio'], dayfirst=True, errors='coerce')

# %%
# Ver los tipos de datos de cada columna
print("Tipos de datos de cada columna:")
print(inventario_completo.dtypes)

#  Ver cuántos valores nulos hay en cada columna
print("Número de valores nulos por columna:")
print(inventario_completo.isnull().sum())
# Out:
# Tipos de datos de cada columna:
# Número                        float64
# Código Ayto                   float64
# Centro                         object
# Dirección                      object
# Coordenada-X                  float64
# Coordenada-Y                  float64
# Latitud                       float64
# Longitud                      float64
# Superficie (m2)               float64
# Uso del edificio               object
# Adscripción                    object
# Distrito                       object
# Potencia KWp                  float64
# Empresa instaladora            object
# Puesta en servicio     datetime64[ns]
# dtype: object
# Número de valores nulos por columna:
# Número                 267
# Código Ayto            307
# Centro                   1
# Dirección              267
# Coordenada-X             8
# Coordenada-Y             7
# Latitud                  1
# Longitud                 3
# Superficie (m2)        520
# Uso del edificio         1
# Adscripción            267
# Distrito                 1
# Potencia KWp           362
# Empresa instaladora    180
# Puesta en servicio      50
# dtype: int64

# %% [markdown]
# --------------------------------

# %%
# Definir las columnas en las que quieres eliminar las filas que tengan valores nulos
columnas_requeridas = ['Distrito', 'Uso del edificio', 'Coordenada-X', 'Coordenada-Y', 'Latitud', 'Longitud', 'Centro']

# Eliminar las filas con valores nulos en cualquiera de las columnas especificadas
inventario_completo = inventario_completo.dropna(subset=columnas_requeridas)

# %%
#  Ver cuántos valores nulos hay en cada columna
print("Número de valores nulos por columna:")
print(inventario_completo.isnull().sum())
# Out:
# Número de valores nulos por columna:
# Número                 259
# Código Ayto            299
# Centro                   0
# Dirección              259
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        510
# Uso del edificio         0
# Adscripción            259
# Distrito                 0
# Potencia KWp           353
# Empresa instaladora    176
# Puesta en servicio      49
# dtype: int64

# %% [markdown]
# ## como he interpretado cada columna:
# Número: Es probable que sea un identificador único asignado a cada instalación dentro del inventario para su referencia.
#
# Código Ayto: Este podría ser el código del ayuntamiento o municipio donde se ubica la instalación fotovoltaica.
#
# Centro: Podría referirse al nombre del centro o la ubicación específica donde está instalada la planta fotovoltaica (por ejemplo, un edificio, institución, etc.).
#
# Dirección: La dirección exacta donde está ubicada la instalación, que puede incluir calle, número y otros datos de ubicación.
#
# Coordenada-X: Representa la coordenada X en un sistema de referencia de coordenadas (posiblemente en UTM) que indica la posición en el eje horizontal (este-oeste).
#
# Coordenada-Y: Representa la coordenada Y en un sistema de referencia de coordenadas, que indica la posición en el eje vertical (norte-sur).
#
# Latitud: La latitud geográfica de la instalación, expresada en grados decimales, que indica su posición en el eje norte-sur en coordenadas geográficas.
#
# Longitud: La longitud geográfica de la instalación, expresada en grados decimales, que indica su posición en el eje este-oeste en coordenadas geográficas.
#
# Superficie (m2): Área en metros cuadrados de la superficie ocupada por la instalación fotovoltaica.
#
# Uso del edificio: Describe el tipo de uso del edificio donde está ubicada la instalación (por ejemplo, residencial, industrial, comercial, institucional, etc.).
#
# Adscripción: Indica a qué entidad o departamento está adscrita la instalación, es decir, quién es el responsable o el propietario de la misma.
#
# Distrito: El distrito o la subdivisión municipal donde se encuentra la instalación.
#
# Potencia KWp: Potencia pico de la instalación en kilovatios (KWp), que indica la máxima potencia que puede generar bajo condiciones óptimas.
#
# Empresa instaladora: Nombre de la empresa encargada de la instalación del sistema fotovoltaico.
#
# Puesta en servicio: La fecha en la que la instalación fue puesta en servicio y comenzó a operar.

# %%
# Crear un mapeo con las direcciones y su código Ayto no nulo
mapeo_codigo_ayto = inventario_completo.groupby('Dirección')['Código Ayto'].apply(lambda x: x.dropna().iloc[0] if not x.dropna().empty else None).to_dict()

# Rellenar los valores nulos en Código Ayto basándose en el mapeo
inventario_completo['Código Ayto'] = inventario_completo.apply(
    lambda row: mapeo_codigo_ayto[row['Dirección']] if pd.isna(row['Código Ayto']) and row['Dirección'] in mapeo_codigo_ayto else row['Código Ayto'], 
    axis=1
)

# %%
#  Ver cuántos valores nulos hay en cada columna
print("Número de valores nulos por columna:")
print(inventario_completo.isnull().sum())
# Out:
# Número de valores nulos por columna:
# Número                 259
# Código Ayto            287
# Centro                   0
# Dirección              259
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        510
# Uso del edificio         0
# Adscripción            259
# Distrito                 0
# Potencia KWp           353
# Empresa instaladora    176
# Puesta en servicio      49
# dtype: int64

# %%
inventario_completo['Código Ayto']
# Out:
# 0      2178.0
# 1       782.0
# 2      2096.0
# 3      1046.0
# 4      2143.0
#         ...
# 737       NaN
# 738       NaN
# 739       NaN
# 740       NaN
# 741       NaN
# Name: Código Ayto, Length: 621, dtype: float64

# %%
# Filtrar filas con valores nulos
filas_con_nulos = inventario_completo[inventario_completo.isna().any(axis=1)]

# Mostrar las filas con valores nulos
filas_con_nulos
# Out:
#      Número  Código Ayto                                     Centro  \
# 0       1.0       2178.0                  BIBLIOTECA ÁNGEL GONZALEZ
# 1       2.0        782.0                  BIBLIOTECA IVÁN DE VARGAS
# 2       3.0       2096.0     BIBLIOTECA EUGENIO TRIAS (CASA FIERAS)
# 4       5.0       2143.0                            MADRID EMPRENDE
# 5       6.0       1779.0                               MARES MADRID
# ..      ...          ...                                        ...
# 737   171.0          NaN  CENTRO MUNICIPAL DE RECOGIDAS TRECE ROSAS
# 738   172.0          NaN                             CDM EL QUIJOTE
# 739   173.0          NaN                               CDM MOSCARDO
# 740   174.0          NaN                CID VILLA DE VALLECAS / OAC
# 741   175.0          NaN         ALMACEN BOMBEROS VILLA DE VALLECAS
#
#                                        Dirección  Coordenada-X  Coordenada-Y  \
# 0                  C/ GRANJA DE TORREHERMOSA, 2       434954.0     4472113.0
# 1                         C/ DOCTOR LETAMENDI, 1      439775.0     4473962.0
# 2                 AV/ MENENDEZ PELAYO , 10-3 BJ       442345.0     4474221.0
# 4                                    C/CIDRO, 3       436689.0     4468938.0
# 5                         C/ FRANCISCO LAGUNA 38      443153.0     4471330.0
# ..                                           ...           ...           ...
# 737  AVENIDA DE LAS TRECE ROSAS, 5, 28017 MADRID      445062.0     4475080.0
# 738                             CALLE NUMANCIA,2      439587.0     4478360.0
# 739                   CALLE PILAR DE ZARAGOZA 93      440125.0     4471120.0
# 740                     CALLE REAL DE ARGANDA 64      447858.0     4470029.0
# 741              CALLE EL REAL DE SAN VICENTE 61      446228.0     4468926.0
#
#        Latitud  Longitud  Superficie (m2) Uso del edificio  \
# 0    40.397075 -3.766489              NaN         cultural
# 1    40.414103 -3.709859              NaN         cultural
# 2    40.416609 -3.679593              NaN         cultural
# 4    40.368616 -3.745730              NaN   administrativo
# 5    40.390628 -3.669802              NaN   administrativo
# ..         ...       ...              ...              ...
# 737  40.424542 -3.647631              NaN   medioambiental
# 738  40.453707 -3.712486              NaN        deportivo
# 739  40.388522 -3.705459              NaN        deportivo
# 740  40.379215 -3.614259              NaN        seguridad
# 741  40.369172 -3.633370              NaN        seguridad
#
#                                            Adscripción               Distrito  \
# 0                       AG Cultura Turismo y Deportes                 Latina
# 1                       AG Cultura Turismo y Deportes                 Centro
# 2                       AG Cultura Turismo y Deportes                 Retiro
# 4                    AG Economía, Innovación y Empleo            Carabanchel
# 5                    AG Economía, Innovación y Empleo    Puente de Vallecas
# ..                                                 ...                    ...
# 737  Area de Gobierno de Urbanismo, Medioambiente y...          CIUDAD LINEAL
# 738                                JMD Moncloa Aravaca      MONCLOA - ARAVACA
# 739                                      JMD Salamanca              SALAMANCA
# 740                              JMD Villa de Vallecas      VILLA DE VALLECAS
# 741                              JMD Villa de Vallecas      VILLA DE VALLECAS
#
#      Potencia KWp Empresa instaladora Puesta en servicio
# 0            20.0               ORTIZ         2019-07-31
# 1             3.0               ORTIZ         2019-07-24
# 2             NaN               ORTIZ         2019-07-24
# 4            10.0                 NaN                NaT
# 5             7.0                 NaN                NaT
# ..            ...                 ...                ...
# 737          10.0                 NaN         2024-07-01
# 738          20.0                 NaN         2024-09-12
# 739          10.0                 NaN         2024-09-11
# 740          10.0                 NaN         2024-09-11
# 741          33.0                 NaN         2024-04-03
#
# [591 rows x 15 columns]

# %%
# Eliminar filas donde todos los valores son nulos
inventario_completo.dropna(how='all', inplace=True)

# %%
#  Ver cuántos valores nulos hay en cada columna
print("Número de valores nulos por columna:")
print(inventario_completo.isnull().sum())
# Out:
# Número de valores nulos por columna:
# Número                 259
# Código Ayto            287
# Centro                   0
# Dirección              259
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        510
# Uso del edificio         0
# Adscripción            259
# Distrito                 0
# Potencia KWp           353
# Empresa instaladora    176
# Puesta en servicio      49
# dtype: int64

# %%
pd.set_option('future.no_silent_downcasting', True)
# Aseguramos que 'Dirección' sea de tipo 'object' (cadena de texto)
inventario_completo['Dirección'] = inventario_completo['Dirección'].astype('object')

# Rellenar los valores nulos en 'Dirección' utilizando ffill y bfill dentro de cada grupo de coordenadas
# Usamos transform para asegurar que el índice no se altere y los resultados se mantengan en su lugar
inventario_completo['Dirección'] = inventario_completo.groupby(['Coordenada-X', 'Coordenada-Y'])['Dirección'].transform(lambda x: x.ffill().bfill())

# %%
#  Ver cuántos valores nulos hay en cada columna
print("Número de valores nulos por columna:")
print(inventario_completo.isnull().sum())
# Out:
# Número de valores nulos por columna:
# Número                 259
# Código Ayto            287
# Centro                   0
# Dirección                1
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        510
# Uso del edificio         0
# Adscripción            259
# Distrito                 0
# Potencia KWp           353
# Empresa instaladora    176
# Puesta en servicio      49
# dtype: int64

# %%
# Filtrar las filas donde 'Dirección' es nula
filas_nulas = inventario_completo[inventario_completo['Dirección'].isnull()]

# Mostrar esas filas
filas_nulas
# Out:
#      Número  Código Ayto        Centro Dirección  Coordenada-X  Coordenada-Y  \
# 568     NaN          NaN  VIVEROS M 30       NaN      437378.7     4477071.3
#
#        Latitud  Longitud  Superficie (m2) Uso del edificio Adscripción  \
# 568  40.441935 -3.738396              NaN   medioambiental         NaN
#
#               Distrito  Potencia KWp Empresa instaladora Puesta en servicio
# 568  MONCLOA - ARAVACA           NaN                 NaN         2023-05-10

# %%
inventario_completo = inventario_completo.dropna(subset=['Dirección'])
#  Ver cuántos valores nulos hay en cada columna
print("Número de valores nulos por columna:")
print(inventario_completo.isnull().sum())
# Out:
# Número de valores nulos por columna:
# Número                 258
# Código Ayto            286
# Centro                   0
# Dirección                0
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        509
# Uso del edificio         0
# Adscripción            258
# Distrito                 0
# Potencia KWp           352
# Empresa instaladora    175
# Puesta en servicio      49
# dtype: int64

# %%
# En lugar de usar inplace=True, asigna el resultado de fillna directamente al DataFrame
inventario_completo['Adscripción'] = inventario_completo['Adscripción'].fillna("No especificado")
inventario_completo['Empresa instaladora'] = inventario_completo['Empresa instaladora'].fillna("Empresa desconocida")

# Verificar si hay valores nulos restantes
print(inventario_completo.isnull().sum())
# Out:
# Número                 258
# Código Ayto            286
# Centro                   0
# Dirección                0
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        509
# Uso del edificio         0
# Adscripción              0
# Distrito                 0
# Potencia KWp           352
# Empresa instaladora      0
# Puesta en servicio      49
# dtype: int64

# %%
# Crear un mapeo: para cada Dirección, asignar el primer Código Ayto no nulo encontrado
mapeo_codigo_ayto = inventario_completo.groupby('Dirección')['Código Ayto'].apply(lambda x: x.dropna().iloc[0] if not x.dropna().empty else None).to_dict()

# Usar el mapeo para rellenar los valores nulos en "Código Ayto" basándose en "Dirección"
inventario_completo['Código Ayto'] = inventario_completo.apply(
    lambda row: mapeo_codigo_ayto[row['Dirección']] if pd.isna(row['Código Ayto']) and row['Dirección'] in mapeo_codigo_ayto else row['Código Ayto'], 
    axis=1
)

# Verificar si hay valores nulos restantes
print(inventario_completo.isnull().sum())
# Out:
# Número                 258
# Código Ayto             40
# Centro                   0
# Dirección                0
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        509
# Uso del edificio         0
# Adscripción              0
# Distrito                 0
# Potencia KWp           352
# Empresa instaladora      0
# Puesta en servicio      49
# dtype: int64

# %%
# Mostrar las 40 primeras filas donde "Código Ayto" sea nulo
nulas_codigo_ayto = inventario_completo[inventario_completo['Código Ayto'].isnull()]
nulas_codigo_ayto.head(40)
# Out:
#      Número  Código Ayto                                            Centro  \
# 9      10.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 10     11.0          NaN                 VIVERO MUNICIPAL DE CASA DE CAMPO
# 11     12.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 12     13.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 42     43.0          NaN              EI POETA GLORIA FUERTES (LAS TABLAS)
# 90     91.0          NaN                       CASA ASOCIACIONES HORTALEZA
# 91     92.0          NaN                                       EI PLÉYADES
# 108    10.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 109    12.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 110    13.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 188    91.0          NaN       CC RUBÉN DARÍO/CASA ASOCIACIONES HORTALEZA
# 189    92.0          NaN                                       EI PLÉYADES
# 213     NaN          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 214     NaN          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 215     NaN          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 292     NaN          NaN  CAF-2 y Casa de NiÃ±os (antes CC RubÃ©n DarÃ­o)
# 293     NaN          NaN                                      EI PLÃYADES
# 440     NaN          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 441     NaN          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 442     NaN          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 519     NaN          NaN  CAF-2 y Casa de NiÃ±os (antes CC RubÃ©n DarÃ­o)
# 520     NaN          NaN                                      EI PLÃYADES
# 550     NaN          NaN                                    INNOVATION LAB
# 552     NaN          NaN           CDM BLANCA FDEZ OCHOA (ANTIGUA LA MINA)
# 591     9.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 592    10.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 593    11.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 670    89.0          NaN     CAF-2 y Casa de Niños (antes CC Rubén Darío)
# 671    90.0          NaN                                       EI PLÉYADES
# 701   134.0          NaN                                    INNOVATION LAB
# 703   136.0          NaN           CDM BLANCA FDEZ OCHOA (ANTIGUA LA MINA)
# 732   166.0          NaN                   CENTRO CULTURAL PASTORA IMPERIO
# 733   167.0          NaN                                EI LAS GOLONDRINAS
# 735   169.0          NaN                 FACTORÍA INDUSTRIAL DE VILLAVERDE
# 736   170.0          NaN                            CEIP CIUDAD DE CORDOBA
# 737   171.0          NaN         CENTRO MUNICIPAL DE RECOGIDAS TRECE ROSAS
# 738   172.0          NaN                                    CDM EL QUIJOTE
# 739   173.0          NaN                                      CDM MOSCARDO
# 740   174.0          NaN                       CID VILLA DE VALLECAS / OAC
# 741   175.0          NaN                ALMACEN BOMBEROS VILLA DE VALLECAS
#
#                                              Dirección  Coordenada-X  \
# 9    Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 10             Pº Azul s/n. Parque de la Casa de Campo      438584.0
# 11   Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 12   c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 42           C/ EUNATE 6 C/CASTILLO DE CANDANCHÚ 42-46      442700.0
# 90                                CALLE MATAPOZUELOS 6      444896.0
# 91                          AVENIDA SECUNDINO ZUAZO 52      447428.0
# 108  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 109  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 110  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 188                               CALLE MATAPOZUELOS 2      444896.0
# 189                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 213  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 214  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 215  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 292                               CALLE MATAPOZUELOS 2      444896.0
# 293                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 440  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 441  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 442  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 519                               CALLE MATAPOZUELOS 2      444896.0
# 520                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 550                                         C/CAROLI 1      440257.8
# 552               Calle de Monseñor Oscar Romero, nº41      436647.8
# 591  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 592  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 593  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 670                               CALLE MATAPOZUELOS 2      444896.0
# 671                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 701                                         C/CAROLI 1      440257.8
# 703               Calle de Monseñor Oscar Romero, nº41      436647.8
# 732                                 PASTORA IMPERIO 4B      442760.8
# 733           C/ JOSEFA VALCARCEL ,158 , 28022, MADRID      448254.3
# 735                              AVD REAL DE PINTO 166      439160.0
# 736                    CALLE MENASALBAS,6,28041 MADRID      440897.0
# 737        AVENIDA DE LAS TRECE ROSAS, 5, 28017 MADRID      445062.0
# 738                                   CALLE NUMANCIA,2      439587.0
# 739                         CALLE PILAR DE ZARAGOZA 93      440125.0
# 740                           CALLE REAL DE ARGANDA 64      447858.0
# 741                    CALLE EL REAL DE SAN VICENTE 61      446228.0
#
#      Coordenada-Y    Latitud  Longitud  Superficie (m2) Uso del edificio  \
# 9       4473428.0  40.409435 -3.686180              NaN   medioambiental
# 10      4474694.0  40.420606 -3.723958              NaN   medioambiental
# 11      4476508.0  40.436863 -3.738172              NaN   medioambiental
# 12      4475363.0  40.426646 -3.721771              NaN   medioambiental
# 42      4484024.0  40.504951 -3.676283              NaN        educativo
# 90      4479194.0  40.461589 -3.649947              NaN           social
# 91      4482921.0  40.495330 -3.620386              NaN        educativo
# 108     4473428.0  40.409435 -3.686180              NaN   medioambiental
# 109     4476508.0  40.436863 -3.738172              NaN   medioambiental
# 110     4475363.0  40.426646 -3.721771              NaN   medioambiental
# 188     4479194.0  40.461589 -3.649947              NaN            mixto
# 189     4482921.0  40.495330 -3.620386              NaN        educativo
# 213     4473428.0  40.409435 -3.686180              NaN   medioambiental
# 214     4476508.0  40.436863 -3.738172              NaN   medioambiental
# 215     4475363.0  40.426646 -3.721771              NaN   medioambiental
# 292     4479194.0  40.461589 -3.649947              NaN            mixto
# 293     4482921.0  40.495330 -3.620386              NaN        educativo
# 440     4473428.0  40.409435 -3.686180              NaN   medioambiental
# 441     4476508.0  40.436863 -3.738172              NaN   medioambiental
# 442     4475363.0  40.426646 -3.721771              NaN   medioambiental
# 519     4479194.0  40.461589 -3.649947              NaN            mixto
# 520     4482921.0  40.495330 -3.620386              NaN        educativo
# 550     4476473.1  40.436758 -3.704833              NaN         cultural
# 552     4470488.0  40.382541 -3.746873              NaN        deportivo
# 591     4473428.0  40.409435 -3.686180              NaN   medioambiental
# 592     4476508.0  40.436863 -3.738172              NaN   medioambiental
# 593     4475363.0  40.426646 -3.721771              NaN   medioambiental
# 670     4479194.0  40.461589 -3.649947              NaN            mixto
# 671     4482921.0  40.495330 -3.620386              NaN        educativo
# 701     4476473.1  40.436758 -3.704833              NaN         cultural
# 703     4470488.0  40.382541 -3.746873              NaN        deportivo
# 732     4481592.7  40.483054 -3.675345              NaN         cultural
# 733     4477795.9  40.449210 -3.610224              NaN        educativo
# 735     4464652.0  40.330191 -3.716211              NaN       industrial
# 736     4468239.0  40.362623 -3.696088              NaN        educativo
# 737     4475080.0  40.424542 -3.647631              NaN   medioambiental
# 738     4478360.0  40.453707 -3.712486              NaN        deportivo
# 739     4471120.0  40.388522 -3.705459              NaN        deportivo
# 740     4470029.0  40.379215 -3.614259              NaN        seguridad
# 741     4468926.0  40.369172 -3.633370              NaN        seguridad
#
#                                            Adscripción               Distrito  \
# 9                    AG de Medio Ambiente y Movilidad                 Retiro
# 10                   AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 11                   AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 12                   AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 42                            JMD Fuercarral El Pardo    Fuencarral El Pardo
# 90                                      JMD Hortaleza              Hortaleza
# 91                                      JMD Hortaleza              Hortaleza
# 108                  AG de Medio Ambiente y Movilidad                 Retiro
# 109                  AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 110                  AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 188                                     JMD Hortaleza              Hortaleza
# 189                                     JMD Hortaleza              Hortaleza
# 213                                    No especificado                 Retiro
# 214                                    No especificado        Moncloa Aravaca
# 215                                    No especificado        Moncloa Aravaca
# 292                                    No especificado              Hortaleza
# 293                                    No especificado              Hortaleza
# 440                                    No especificado                 RETIRO
# 441                                    No especificado      MONCLOA - ARAVACA
# 442                                    No especificado      MONCLOA - ARAVACA
# 519                                    No especificado              HORTALEZA
# 520                                    No especificado              HORTALEZA
# 550                                    No especificado      MONCLOA - ARAVACA
# 552                                    No especificado            CARABANCHEL
# 591                   AG de Medio Ambiente y Movilidad                 RETIRO
# 592                   AG de Medio Ambiente y Movilidad      MONCLOA - ARAVACA
# 593                   AG de Medio Ambiente y Movilidad      MONCLOA - ARAVACA
# 670                                      JMD Hortaleza              HORTALEZA
# 671                                      JMD Hortaleza              HORTALEZA
# 701                    AG economia Innovacion y Empleo      MONCLOA - ARAVACA
# 703                                    JMD Carabanchel            CARABANCHEL
# 732                                      JMD Chamartín              CHAMARTIN
# 733                            JMD San Blas Canillejas  SAN BLAS - CANILLEJAS
# 735                    AG economia Innovacion y Empleo             VILLAVERDE
# 736                                     JMD Villaverde             VILLAVERDE
# 737  Area de Gobierno de Urbanismo, Medioambiente y...          CIUDAD LINEAL
# 738                                JMD Moncloa Aravaca      MONCLOA - ARAVACA
# 739                                      JMD Salamanca              SALAMANCA
# 740                              JMD Villa de Vallecas      VILLA DE VALLECAS
# 741                              JMD Villa de Vallecas      VILLA DE VALLECAS
#
#      Potencia KWp        Empresa instaladora Puesta en servicio
# 9             5.0        Empresa desconocida                NaT
# 10            5.0        Empresa desconocida                NaT
# 11            5.0        Empresa desconocida                NaT
# 12            5.0        Empresa desconocida                NaT
# 42            NaN                    CONDISA         2019-02-12
# 90            9.0        Empresa desconocida         2020-03-23
# 91            NaN        Empresa desconocida                NaT
# 108           NaN        Empresa desconocida                NaT
# 109           NaN        Empresa desconocida                NaT
# 110           NaN                    SAVEFFI                NaT
# 188           NaN        Empresa desconocida                NaT
# 189           NaN                    SAVEFFI                NaT
# 213           NaN        Empresa desconocida                NaT
# 214           NaN        Empresa desconocida                NaT
# 215           NaN        Empresa desconocida                NaT
# 292           NaN                    SAVEFFI         2020-03-25
# 293           NaN        Empresa desconocida                NaT
# 440           5.0        Empresa desconocida                NaT
# 441           NaN        Empresa desconocida                NaT
# 442           5.0        Empresa desconocida                NaT
# 519           9.0                    SAVEFFI         2020-03-25
# 520           NaN        Empresa desconocida                NaT
# 550          10.0        Empresa desconocida         2022-05-26
# 552           NaN  ACCIONA FACILITY SERVICES         2022-11-07
# 591           5.0        Empresa desconocida                NaT
# 592           NaN        Empresa desconocida                NaT
# 593           5.0        Empresa desconocida                NaT
# 670           9.0                    SAVEFFI         2020-03-25
# 671           NaN        Empresa desconocida                NaT
# 701          10.0        Empresa desconocida         2022-05-26
# 703           NaN  ACCIONA FACILITY SERVICES         2022-11-07
# 732          10.0        Empresa desconocida         2024-02-29
# 733          15.0        Empresa desconocida         2023-03-21
# 735           6.0       HERRERA Y LOBATOS.L.         2020-11-27
# 736           4.0        Empresa desconocida         2024-06-18
# 737          10.0        Empresa desconocida         2024-07-01
# 738          20.0        Empresa desconocida         2024-09-12
# 739          10.0        Empresa desconocida         2024-09-11
# 740          10.0        Empresa desconocida         2024-09-11
# 741          33.0        Empresa desconocida         2024-04-03

# %%
# Rellenar con la fecha anterior (forward fill)
inventario_completo['Puesta en servicio'] = inventario_completo['Puesta en servicio'].ffill()

# O si prefieres con la fecha siguiente (backward fill)
inventario_completo['Puesta en servicio'] = inventario_completo['Puesta en servicio'].bfill()

# Verificar si hay nulos restantes
print(inventario_completo['Puesta en servicio'].isnull().sum())
# Out:
# 0

# %%
import pandas as pd

inventario_completo['Número'] = inventario_completo.apply(
    lambda row: row.name + 1 if pd.isnull(row['Número']) else row['Número'], axis=1
)

# %%
# Verificar si hay valores nulos restantes
print(inventario_completo.isnull().sum())
# Out:
# Número                   0
# Código Ayto             40
# Centro                   0
# Dirección                0
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        509
# Uso del edificio         0
# Adscripción              0
# Distrito                 0
# Potencia KWp           352
# Empresa instaladora      0
# Puesta en servicio       0
# dtype: int64

# %%
# a. Promedio por categoría de uso del edificio
inventario_completo['Superficie (m2)'] = inventario_completo.groupby('Uso del edificio')['Superficie (m2)'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
# b. Inferencia por tamaño del edificio (relación superficie-potencia)
# Verificar si existe una relación significativa entre superficie y potencia
if inventario_completo['Superficie (m2)'].notnull().any():
    from sklearn.linear_model import LinearRegression

    # Filtrar datos sin nulos para entrenar el modelo
    potencia_model_data = inventario_completo.dropna(subset=['Superficie (m2)', 'Potencia KWp'])

    # Entrenar modelo de regresión
    reg = LinearRegression()
    reg.fit(potencia_model_data[['Superficie (m2)']], potencia_model_data['Potencia KWp'])

    # Predecir valores nulos
    potencia_null_mask = inventario_completo['Potencia KWp'].isnull() & inventario_completo['Superficie (m2)'].notnull()
    inventario_completo.loc[potencia_null_mask, 'Potencia KWp'] = reg.predict(
        inventario_completo.loc[potencia_null_mask, ['Superficie (m2)']]
    )

# %%
from sklearn.linear_model import LinearRegression

# Filtrar datos sin nulos para entrenar el modelo
superficie_model_data = inventario_completo.dropna(subset=['Superficie (m2)', 'Potencia KWp'])

# Entrenar el modelo de regresión lineal
reg = LinearRegression()
reg.fit(superficie_model_data[['Potencia KWp']], superficie_model_data['Superficie (m2)'])

# Predecir valores nulos de 'Superficie (m2)' basados en 'Potencia KWp'
superficie_null_mask = inventario_completo['Superficie (m2)'].isnull() & inventario_completo['Potencia KWp'].notnull()
inventario_completo.loc[superficie_null_mask, 'Superficie (m2)'] = reg.predict(
    inventario_completo.loc[superficie_null_mask, ['Potencia KWp']]
)

# %%
# Verificar si hay valores nulos restantes
print(inventario_completo.isnull().sum())
# Out:
# Número                   0
# Código Ayto             40
# Centro                   0
# Dirección                0
# Coordenada-X             0
# Coordenada-Y             0
# Latitud                  0
# Longitud                 0
# Superficie (m2)        110
# Uso del edificio         0
# Adscripción              0
# Distrito                 0
# Potencia KWp           110
# Empresa instaladora      0
# Puesta en servicio       0
# dtype: int64

# %%
# Filtrar filas con valores nulos en cualquier columna del DataFrame
nulos_completos = inventario_completo[inventario_completo.isnull().any(axis=1)]

# Mostrar las filas con nulos
nulos_completos
# Out:
#      Número  Código Ayto                                     Centro  \
# 8       9.0        317.0   AULA DE LA NATURALEZA DEHESA DE LA VILLA
# 9      10.0          NaN     VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 10     11.0          NaN          VIVERO MUNICIPAL DE CASA DE CAMPO
# 11     12.0          NaN        VIVERO MUNICIPAL DE MIGAS CALIENTES
# 12     13.0          NaN              ROSALEDA DEL PARQUE DEL OESTE
# ..      ...          ...                                        ...
# 737   171.0          NaN  CENTRO MUNICIPAL DE RECOGIDAS TRECE ROSAS
# 738   172.0          NaN                             CDM EL QUIJOTE
# 739   173.0          NaN                               CDM MOSCARDO
# 740   174.0          NaN                CID VILLA DE VALLECAS / OAC
# 741   175.0          NaN         ALMACEN BOMBEROS VILLA DE VALLECAS
#
#                                              Dirección  Coordenada-X  \
# 8                            C/ FRANCOS RODRIGUEZ, 97       439102.0
# 9    Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 10             Pº Azul s/n. Parque de la Casa de Campo      438584.0
# 11   Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 12   c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# ..                                                 ...           ...
# 737        AVENIDA DE LAS TRECE ROSAS, 5, 28017 MADRID      445062.0
# 738                                   CALLE NUMANCIA,2      439587.0
# 739                         CALLE PILAR DE ZARAGOZA 93      440125.0
# 740                           CALLE REAL DE ARGANDA 64      447858.0
# 741                    CALLE EL REAL DE SAN VICENTE 61      446228.0
#
#      Coordenada-Y    Latitud  Longitud  Superficie (m2) Uso del edificio  \
# 8       4478967.0  40.459141 -3.718271              NaN   medioambiental
# 9       4473428.0  40.409435 -3.686180      1108.709608   medioambiental
# 10      4474694.0  40.420606 -3.723958      1108.709608   medioambiental
# 11      4476508.0  40.436863 -3.738172      1108.709608   medioambiental
# 12      4475363.0  40.426646 -3.721771      1108.709608   medioambiental
# ..            ...        ...       ...              ...              ...
# 737     4475080.0  40.424542 -3.647631      1505.375826   medioambiental
# 738     4478360.0  40.453707 -3.712486      4661.848686        deportivo
# 739     4471120.0  40.388522 -3.705459      4661.848686        deportivo
# 740     4470029.0  40.379215 -3.614259      1505.375826        seguridad
# 741     4468926.0  40.369172 -3.633370      3330.040429        seguridad
#
#                                            Adscripción           Distrito  \
# 8                    AG de Medio Ambiente y Movilidad    Moncloa Aravaca
# 9                    AG de Medio Ambiente y Movilidad             Retiro
# 10                   AG de Medio Ambiente y Movilidad    Moncloa Aravaca
# 11                   AG de Medio Ambiente y Movilidad    Moncloa Aravaca
# 12                   AG de Medio Ambiente y Movilidad    Moncloa Aravaca
# ..                                                 ...                ...
# 737  Area de Gobierno de Urbanismo, Medioambiente y...      CIUDAD LINEAL
# 738                                JMD Moncloa Aravaca  MONCLOA - ARAVACA
# 739                                      JMD Salamanca          SALAMANCA
# 740                              JMD Villa de Vallecas  VILLA DE VALLECAS
# 741                              JMD Villa de Vallecas  VILLA DE VALLECAS
#
#      Potencia KWp  Empresa instaladora Puesta en servicio
# 8             NaN  Empresa desconocida         2008-08-13
# 9             5.0  Empresa desconocida         2008-08-13
# 10            5.0  Empresa desconocida         2008-08-13
# 11            5.0  Empresa desconocida         2008-08-13
# 12            5.0  Empresa desconocida         2008-08-13
# ..            ...                  ...                ...
# 737          10.0  Empresa desconocida         2024-07-01
# 738          20.0  Empresa desconocida         2024-09-12
# 739          10.0  Empresa desconocida         2024-09-11
# 740          10.0  Empresa desconocida         2024-09-11
# 741          33.0  Empresa desconocida         2024-04-03
#
# [136 rows x 15 columns]

# %%
# Rellenar los valores nulos en 'Superficie (m2)' con el promedio de cada grupo de 'Uso del edificio'
inventario_completo['Superficie (m2)'] = inventario_completo.groupby('Uso del edificio')['Superficie (m2)'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
# Filtrar los datos que no tengan valores nulos en 'Superficie (m2)' y 'Potencia KWp'
potencia_model_data = inventario_completo.dropna(subset=['Superficie (m2)', 'Potencia KWp'])

# Convertir las variables categóricas en dummies (usando pd.get_dummies)
X = pd.get_dummies(potencia_model_data[['Superficie (m2)', 'Uso del edificio']], drop_first=True)
y = potencia_model_data['Potencia KWp']

# Entrenar el modelo
reg = LinearRegression()
reg.fit(X, y)

# Crear el DataFrame para las filas con valores nulos en 'Potencia KWp'
potencia_null_mask = inventario_completo['Potencia KWp'].isnull() & inventario_completo['Superficie (m2)'].notnull()
X_null = pd.get_dummies(inventario_completo.loc[potencia_null_mask, ['Superficie (m2)', 'Uso del edificio']], drop_first=True)

# Asegurar que el DataFrame de predicción tenga las mismas columnas que el de entrenamiento
X_null = X_null.reindex(columns=X.columns, fill_value=0)

# Predecir los valores faltantes
inventario_completo.loc[potencia_null_mask, 'Potencia KWp'] = reg.predict(X_null)

# %%
# Rellenar los valores nulos de la columna 'Superficie (m2)' con la media
inventario_completo['Superficie (m2)'] = inventario_completo['Superficie (m2)'].fillna(inventario_completo['Superficie (m2)'].mean())

# Rellenar los valores nulos de la columna 'Potencia KWp' con la media
inventario_completo['Potencia KWp'] = inventario_completo['Potencia KWp'].fillna(inventario_completo['Potencia KWp'].mean())

# %%
# Verificar si hay valores nulos restantes
print(inventario_completo.isnull().sum())
# Out:
# Número                  0
# Código Ayto            40
# Centro                  0
# Dirección               0
# Coordenada-X            0
# Coordenada-Y            0
# Latitud                 0
# Longitud                0
# Superficie (m2)         0
# Uso del edificio        0
# Adscripción             0
# Distrito                0
# Potencia KWp            0
# Empresa instaladora     0
# Puesta en servicio      0
# dtype: int64

# %%
# Filtrar filas con valores nulos en cualquier columna del DataFrame
nulos_completos = inventario_completo[inventario_completo.isnull().any(axis=1)]

# Mostrar las filas con nulos
nulos_completos
# Out:
#      Número  Código Ayto                                            Centro  \
# 9      10.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 10     11.0          NaN                 VIVERO MUNICIPAL DE CASA DE CAMPO
# 11     12.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 12     13.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 42     43.0          NaN              EI POETA GLORIA FUERTES (LAS TABLAS)
# 90     91.0          NaN                       CASA ASOCIACIONES HORTALEZA
# 91     92.0          NaN                                       EI PLÉYADES
# 108    10.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 109    12.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 110    13.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 188    91.0          NaN       CC RUBÉN DARÍO/CASA ASOCIACIONES HORTALEZA
# 189    92.0          NaN                                       EI PLÉYADES
# 213   214.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 214   215.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 215   216.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 292   293.0          NaN  CAF-2 y Casa de NiÃ±os (antes CC RubÃ©n DarÃ­o)
# 293   294.0          NaN                                      EI PLÃYADES
# 440   441.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 441   442.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 442   443.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 519   520.0          NaN  CAF-2 y Casa de NiÃ±os (antes CC RubÃ©n DarÃ­o)
# 520   521.0          NaN                                      EI PLÃYADES
# 550   551.0          NaN                                    INNOVATION LAB
# 552   553.0          NaN           CDM BLANCA FDEZ OCHOA (ANTIGUA LA MINA)
# 591     9.0          NaN            VIVERO MUNICIPAL DE ESTUFAS DEL RETIRO
# 592    10.0          NaN               VIVERO MUNICIPAL DE MIGAS CALIENTES
# 593    11.0          NaN                     ROSALEDA DEL PARQUE DEL OESTE
# 670    89.0          NaN     CAF-2 y Casa de Niños (antes CC Rubén Darío)
# 671    90.0          NaN                                       EI PLÉYADES
# 701   134.0          NaN                                    INNOVATION LAB
# 703   136.0          NaN           CDM BLANCA FDEZ OCHOA (ANTIGUA LA MINA)
# 732   166.0          NaN                   CENTRO CULTURAL PASTORA IMPERIO
# 733   167.0          NaN                                EI LAS GOLONDRINAS
# 735   169.0          NaN                 FACTORÍA INDUSTRIAL DE VILLAVERDE
# 736   170.0          NaN                            CEIP CIUDAD DE CORDOBA
# 737   171.0          NaN         CENTRO MUNICIPAL DE RECOGIDAS TRECE ROSAS
# 738   172.0          NaN                                    CDM EL QUIJOTE
# 739   173.0          NaN                                      CDM MOSCARDO
# 740   174.0          NaN                       CID VILLA DE VALLECAS / OAC
# 741   175.0          NaN                ALMACEN BOMBEROS VILLA DE VALLECAS
#
#                                              Dirección  Coordenada-X  \
# 9    Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 10             Pº Azul s/n. Parque de la Casa de Campo      438584.0
# 11   Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 12   c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 42           C/ EUNATE 6 C/CASTILLO DE CANDANCHÚ 42-46      442700.0
# 90                                CALLE MATAPOZUELOS 6      444896.0
# 91                          AVENIDA SECUNDINO ZUAZO 52      447428.0
# 108  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 109  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 110  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 188                               CALLE MATAPOZUELOS 2      444896.0
# 189                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 213  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 214  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 215  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 292                               CALLE MATAPOZUELOS 2      444896.0
# 293                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 440  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 441  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 442  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 519                               CALLE MATAPOZUELOS 2      444896.0
# 520                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 550                                         C/CAROLI 1      440257.8
# 552               Calle de Monseñor Oscar Romero, nº41      436647.8
# 591  Pza. del Ángel Caído. Parque del Retiro \n(Ent...      441779.0
# 592  Km. 22. M-30 (frente a palacio Moncloa)\n M-30...      437394.0
# 593  c/ de la Rosaleda s/n. Rosaleda del Parque del...      438775.0
# 670                               CALLE MATAPOZUELOS 2      444896.0
# 671                         AVENIDA SECUNDINO ZUAZO 52      447428.0
# 701                                         C/CAROLI 1      440257.8
# 703               Calle de Monseñor Oscar Romero, nº41      436647.8
# 732                                 PASTORA IMPERIO 4B      442760.8
# 733           C/ JOSEFA VALCARCEL ,158 , 28022, MADRID      448254.3
# 735                              AVD REAL DE PINTO 166      439160.0
# 736                    CALLE MENASALBAS,6,28041 MADRID      440897.0
# 737        AVENIDA DE LAS TRECE ROSAS, 5, 28017 MADRID      445062.0
# 738                                   CALLE NUMANCIA,2      439587.0
# 739                         CALLE PILAR DE ZARAGOZA 93      440125.0
# 740                           CALLE REAL DE ARGANDA 64      447858.0
# 741                    CALLE EL REAL DE SAN VICENTE 61      446228.0
#
#      Coordenada-Y    Latitud  Longitud  Superficie (m2) Uso del edificio  \
# 9       4473428.0  40.409435 -3.686180      1108.709608   medioambiental
# 10      4474694.0  40.420606 -3.723958      1108.709608   medioambiental
# 11      4476508.0  40.436863 -3.738172      1108.709608   medioambiental
# 12      4475363.0  40.426646 -3.721771      1108.709608   medioambiental
# 42      4484024.0  40.504951 -3.676283      1459.251847        educativo
# 90      4479194.0  40.461589 -3.649947       751.795750           social
# 91      4482921.0  40.495330 -3.620386      1459.251847        educativo
# 108     4473428.0  40.409435 -3.686180      1212.453080   medioambiental
# 109     4476508.0  40.436863 -3.738172      1212.453080   medioambiental
# 110     4475363.0  40.426646 -3.721771      1212.453080   medioambiental
# 188     4479194.0  40.461589 -3.649947      3792.795773            mixto
# 189     4482921.0  40.495330 -3.620386      1459.251847        educativo
# 213     4473428.0  40.409435 -3.686180      1212.453080   medioambiental
# 214     4476508.0  40.436863 -3.738172      1212.453080   medioambiental
# 215     4475363.0  40.426646 -3.721771      1212.453080   medioambiental
# 292     4479194.0  40.461589 -3.649947      3792.795773            mixto
# 293     4482921.0  40.495330 -3.620386      1459.251847        educativo
# 440     4473428.0  40.409435 -3.686180      1108.709608   medioambiental
# 441     4476508.0  40.436863 -3.738172      1212.453080   medioambiental
# 442     4475363.0  40.426646 -3.721771      1108.709608   medioambiental
# 519     4479194.0  40.461589 -3.649947      3792.795773            mixto
# 520     4482921.0  40.495330 -3.620386      1459.251847        educativo
# 550     4476473.1  40.436758 -3.704833      1743.961867         cultural
# 552     4470488.0  40.382541 -3.746873      4661.848686        deportivo
# 591     4473428.0  40.409435 -3.686180      1108.709608   medioambiental
# 592     4476508.0  40.436863 -3.738172      1212.453080   medioambiental
# 593     4475363.0  40.426646 -3.721771      1108.709608   medioambiental
# 670     4479194.0  40.461589 -3.649947      3792.795773            mixto
# 671     4482921.0  40.495330 -3.620386      1459.251847        educativo
# 701     4476473.1  40.436758 -3.704833      1743.961867         cultural
# 703     4470488.0  40.382541 -3.746873      4661.848686        deportivo
# 732     4481592.7  40.483054 -3.675345      1743.961867         cultural
# 733     4477795.9  40.449210 -3.610224      1902.042044        educativo
# 735     4464652.0  40.330191 -3.716211      1188.042852       industrial
# 736     4468239.0  40.362623 -3.696088      1029.376364        educativo
# 737     4475080.0  40.424542 -3.647631      1505.375826   medioambiental
# 738     4478360.0  40.453707 -3.712486      4661.848686        deportivo
# 739     4471120.0  40.388522 -3.705459      4661.848686        deportivo
# 740     4470029.0  40.379215 -3.614259      1505.375826        seguridad
# 741     4468926.0  40.369172 -3.633370      3330.040429        seguridad
#
#                                            Adscripción               Distrito  \
# 9                    AG de Medio Ambiente y Movilidad                 Retiro
# 10                   AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 11                   AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 12                   AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 42                            JMD Fuercarral El Pardo    Fuencarral El Pardo
# 90                                      JMD Hortaleza              Hortaleza
# 91                                      JMD Hortaleza              Hortaleza
# 108                  AG de Medio Ambiente y Movilidad                 Retiro
# 109                  AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 110                  AG de Medio Ambiente y Movilidad        Moncloa Aravaca
# 188                                     JMD Hortaleza              Hortaleza
# 189                                     JMD Hortaleza              Hortaleza
# 213                                    No especificado                 Retiro
# 214                                    No especificado        Moncloa Aravaca
# 215                                    No especificado        Moncloa Aravaca
# 292                                    No especificado              Hortaleza
# 293                                    No especificado              Hortaleza
# 440                                    No especificado                 RETIRO
# 441                                    No especificado      MONCLOA - ARAVACA
# 442                                    No especificado      MONCLOA - ARAVACA
# 519                                    No especificado              HORTALEZA
# 520                                    No especificado              HORTALEZA
# 550                                    No especificado      MONCLOA - ARAVACA
# 552                                    No especificado            CARABANCHEL
# 591                   AG de Medio Ambiente y Movilidad                 RETIRO
# 592                   AG de Medio Ambiente y Movilidad      MONCLOA - ARAVACA
# 593                   AG de Medio Ambiente y Movilidad      MONCLOA - ARAVACA
# 670                                      JMD Hortaleza              HORTALEZA
# 671                                      JMD Hortaleza              HORTALEZA
# 701                    AG economia Innovacion y Empleo      MONCLOA - ARAVACA
# 703                                    JMD Carabanchel            CARABANCHEL
# 732                                      JMD Chamartín              CHAMARTIN
# 733                            JMD San Blas Canillejas  SAN BLAS - CANILLEJAS
# 735                    AG economia Innovacion y Empleo             VILLAVERDE
# 736                                     JMD Villaverde             VILLAVERDE
# 737  Area de Gobierno de Urbanismo, Medioambiente y...          CIUDAD LINEAL
# 738                                JMD Moncloa Aravaca      MONCLOA - ARAVACA
# 739                                      JMD Salamanca              SALAMANCA
# 740                              JMD Villa de Vallecas      VILLA DE VALLECAS
# 741                              JMD Villa de Vallecas      VILLA DE VALLECAS
#
#      Potencia KWp        Empresa instaladora Puesta en servicio
# 9        5.000000        Empresa desconocida         2008-08-13
# 10       5.000000        Empresa desconocida         2008-08-13
# 11       5.000000        Empresa desconocida         2008-08-13
# 12       5.000000        Empresa desconocida         2008-08-13
# 42      15.220080                    CONDISA         2019-02-12
# 90       9.000000        Empresa desconocida         2020-03-23
# 91      15.220080        Empresa desconocida         2020-03-23
# 108      6.307692        Empresa desconocida         2008-08-13
# 109      6.307692        Empresa desconocida         2008-08-13
# 110      6.307692                    SAVEFFI         2008-08-13
# 188     26.671750        Empresa desconocida         2020-03-25
# 189     15.220080                    SAVEFFI         2020-03-25
# 213      6.307692        Empresa desconocida         2008-08-13
# 214      6.307692        Empresa desconocida         2008-08-13
# 215      6.307692        Empresa desconocida         2008-08-13
# 292     26.671750                    SAVEFFI         2020-03-25
# 293     15.220080        Empresa desconocida         2020-03-25
# 440      5.000000        Empresa desconocida         2008-08-13
# 441      6.307692        Empresa desconocida         2008-08-13
# 442      5.000000        Empresa desconocida         2008-08-13
# 519      9.000000                    SAVEFFI         2020-03-25
# 520     15.220080        Empresa desconocida         2020-03-25
# 550     10.000000        Empresa desconocida         2022-05-26
# 552     30.132938  ACCIONA FACILITY SERVICES         2022-11-07
# 591      5.000000        Empresa desconocida         2008-08-13
# 592      6.307692        Empresa desconocida         2008-08-13
# 593      5.000000        Empresa desconocida         2008-08-13
# 670      9.000000                    SAVEFFI         2020-03-25
# 671     15.220080        Empresa desconocida         2020-03-25
# 701     10.000000        Empresa desconocida         2022-05-26
# 703     30.132938  ACCIONA FACILITY SERVICES         2022-11-07
# 732     10.000000        Empresa desconocida         2024-02-29
# 733     15.000000        Empresa desconocida         2023-03-21
# 735      6.000000       HERRERA Y LOBATOS.L.         2020-11-27
# 736      4.000000        Empresa desconocida         2024-06-18
# 737     10.000000        Empresa desconocida         2024-07-01
# 738     20.000000        Empresa desconocida         2024-09-12
# 739     10.000000        Empresa desconocida         2024-09-11
# 740     10.000000        Empresa desconocida         2024-09-11
# 741     33.000000        Empresa desconocida         2024-04-03

# %%
# 1. Rellenar nulos en 'Código Ayto' por las coordenadas X y Y
inventario_completo['Código Ayto'] = inventario_completo.groupby(['Coordenada-X', 'Coordenada-Y'])['Código Ayto'].transform(lambda x: x.ffill().bfill())

# 2. Si aún hay valores nulos, rellenamos por 'Distrito'
inventario_completo['Código Ayto'] = inventario_completo.groupby('Distrito')['Código Ayto'].transform(lambda x: x.ffill().bfill())

# 3. Si aún quedan nulos, rellenamos por 'Dirección'
inventario_completo['Código Ayto'] = inventario_completo.groupby('Dirección')['Código Ayto'].transform(lambda x: x.ffill().bfill())

# Ahora los valores nulos en 'Código Ayto' deberían estar rellenados por las mismas coordenadas, distrito o dirección

# %%
# Verificar si hay valores nulos restantes
print(inventario_completo.isnull().sum())
# Out:
# Número                 0
# Código Ayto            0
# Centro                 0
# Dirección              0
# Coordenada-X           0
# Coordenada-Y           0
# Latitud                0
# Longitud               0
# Superficie (m2)        0
# Uso del edificio       0
# Adscripción            0
# Distrito               0
# Potencia KWp           0
# Empresa instaladora    0
# Puesta en servicio     0
# dtype: int64

# %%
# Guardar el DataFrame limpio en un nuevo archivo CSV
inventario_completo.to_csv('inventario_completo_limpio.csv', index=False, encoding='utf-8')
